# %%
import numpy as np
import healpy as hp
import pandas as pd
import matplotlib.pyplot as plt
import pymaster as nmt

#importing useful libraries

# %%
file_path_1 = "/home/gaiaspapera/Desktop/stage IAS/CMBxunWISE/teo/Dl_agora_mu2_bahamas_076.csv"
df_1 = pd.read_csv(file_path_1)

ell_1 = df_1.iloc[:, 0].to_numpy()
dell_1 = df_1.iloc[:, 1].to_numpy()

plt.plot(ell_1, dell_1)
plt.xlabel("l")
plt.ylabel("D_l")
plt.show()

# %%
file_path_2 = "/home/gaiaspapera/Desktop/stage IAS/CMBxunWISE/teo/Dl_agora_mu2_bahamas_078.csv"
df_2 = pd.read_csv(file_path_2)

ell_2 = df_2.iloc[:, 0].to_numpy()
dell_2 = df_2.iloc[:, 1].to_numpy()

plt.plot(ell_2, dell_2)
plt.xlabel("l")
plt.ylabel("D_l")
plt.show()

# %%
file_path_3 = "/home/gaiaspapera/Desktop/stage IAS/CMBxunWISE/teo/Dl_agora_mu2_bahamas_080.csv"
df_3 = pd.read_csv(file_path_3)

ell_3 = df_3.iloc[:, 0].to_numpy()
dell_3 = df_3.iloc[:, 1].to_numpy()

plt.plot(ell_3, dell_3)
plt.xlabel("l")
plt.ylabel("D_l")
plt.show()
